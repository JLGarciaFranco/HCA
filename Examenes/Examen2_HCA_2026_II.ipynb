# %% [markdown]
# # Examen 2
#
# Fecha de entrega: 17 de abril (13:15)
#
# *Instrucciones.*
#
# 1. Realice un 'git pull' y abre la carpeta de Examenes.
# 2. Lea bien todos los ejercicios del examen, y una vez terminado, descargue su notebook individual a su computadora local y subalo como archivo adjunto a la actividad 'Examen' de Moodle. Tenga cuidado que el examen está configurado para cerrar a las 13:15 en punto.
# 3. Puede hacer uso de todos los notebooks del curso que considere necesario pero no puede visitar páginas diferentes a MACTI (en su versión Moodle o JupyterHub).

# %% [markdown]
# # Ejercicio 1. Temperaturas superficiales del mar
#
# Utilizando la base de datos de HadSST, vista en el curso y disponible en el repositorio, realice lo siguiente:
#
# 1. Realice un slice de las anomalías superficiales del mar, para considerar los datos que se hayan medido a partir de su año de cumpleaños.
# 2. Realice promedios temporales para todos los datos de las estaciones del año (invierno, primavera, otoño y verano).
# 3. Grafique las anomalías promedio de cada estación como mapas de Cartopy en un dominio / extensión de su elección.
# 4. Haga un promedio de área en el Polo Norte (60N-90N) y en el ecuador (10S-10N), además de un promedio global.
# 5. Grafique las anomalías resultantes para los 3 grupos como un boxplot comparando entre las 3 regiones en 1 sólo objeto de figura.
#
# Extras: realice todas las gráficas del punto 3) en un solo objeto de figura usando 'subplots'.

# %% [markdown]
# # Ejercicio 2: Pinguinos
#
#
# Considere la base de datos sobre pinguinos de *seaborn* que puede cargar de la siguiente manera:
#
# `penguins = sns.load_dataset("penguins")`
#
# 1. Haga un gráfico de dispersión de las variables ("flipper_length_mm vs "bill_length_mm"). Haga su gráfica bonita.
# 2. Obtenga los promedios de todas las variables numéricas en el dataframe.
# 3. Repita la operación de los promedios pero agrupando datos a través de la especie de pinguino y en segunda instancia a través del 'sexo' de los pinguinos. Nota: el enunciado del ejercicio sugiere que este procedimiento deberá realizarlo para cada variable numérica.
